# %%
import pandas as pd

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data', header=None, sep='\s+')
df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B' , 'LSTAT', 'MEDV']
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
import numpy as np

cols = ['DIS', 'INDUS', 'CRIM', 'RM', 'MEDV']
cm = np.corrcoef(df[cols].values.T)

# %%
import seaborn as sns

sns.set(style='whitegrid', context='notebook')

sns.heatmap(cm, cbar=True, annot=True, xticklabels=cols, yticklabels=cols)
# Out:
# <Axes: >

# %%
x = df[['RM', 'INDUS']].values
x
# Out:
# array([[ 6.575,  2.31 ],
#        [ 6.421,  7.07 ],
#        [ 7.185,  7.07 ],
#        ...,
#        [ 6.976, 11.93 ],
#        [ 6.794, 11.93 ],
#        [ 6.03 , 11.93 ]])

# %%
# Variables de correlación más alta: RM; INDUS

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# x = df[['RM', 'INDUS']].values
y = df['MEDV'].values.reshape(-1, 1)

sc_x = StandardScaler()
sc_y = StandardScaler()

x_std = sc_x.fit_transform(x)
y_std= sc_y.fit_transform(y)

slr = LinearRegression()
slr.fit(x_std, y_std)
# Out:
# LinearRegression()

# %%
# Análisis de resultados, gráfico de tres dimensiones

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import *
import numpy as np

# %%
x1_range = np.arange(df['RM'].min(), df['RM'].max())
x1_range
# Out:
# array([3.561, 4.561, 5.561, 6.561, 7.561, 8.561])

# %%
x2_range = np.arange(df['INDUS'].min(), df['INDUS'].max())
x2_range
# Out:
# array([ 0.46,  1.46,  2.46,  3.46,  4.46,  5.46,  6.46,  7.46,  8.46,
#         9.46, 10.46, 11.46, 12.46, 13.46, 14.46, 15.46, 16.46, 17.46,
#        18.46, 19.46, 20.46, 21.46, 22.46, 23.46, 24.46, 25.46, 26.46,
#        27.46])

# %%
x1, x2 = np.meshgrid(x1_range, x2_range)
x1, x2
# Out:
# (array([[3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561],
#         [3.561, 4.561, 5.561, 6.561, 7.561, 8.561]]),
#  array([[ 0.46,  0.46,  0.46,  0.46,  0.46,  0.46],
#         [ 1.46,  1.46,  1.46,  1.46,  1.46,  1.46],
#         [ 2.46,  2.46,  2.46,  2.46,  2.46,  2.46],
#         [ 3.46,  3.46,  3.46,  3.46,  3.46,  3.46],
#         [ 4.46,  4.46,  4.46,  4.46,  4.46,  4.46],
#         [ 5.46,  5.46,  5.46,  5.46,  5.46,  5.46],
#         [ 6.46,  6.46,  6.46,  6.46,  6.46,  6.46],
#         [ 7.46,  7.46,  7.46,  7.46,  7.46,  7.46],
#         [ 8.46,  8.46,  8.46,  8.46,  8.46,  8.46],
#         [ 9.46,  9.46,  9.46,  9.46,  9.46,  9.46],
#         [10.46, 10.46, 10.46, 10.46, 10.46, 10.46],
#         [11.46, 11.46, 11.46, 11.46, 11.46, 11.46],
#         [12.46, 12.46, 12.46, 12.46, 12.46, 12.46],
#         [13.46, 13.46, 13.46, 13.46, 13.46, 13.46],
#         [14.46, 14.46, 14.46, 14.46, 14.46, 14.46],
#         [15.46, 15.46, 15.46, 15.46, 15.46, 15.46],
#         [16.46, 16.46, 16.46, 16.46, 16.46, 16.46],
#         [17.46, 17.46, 17.46, 17.46, 17.46, 17.46],
#         [18.46, 18.46, 18.46, 18.46, 18.46, 18.46],
#         [19.46, 19.46, 19.46, 19.46, 19.46, 19.46],
#         [20.46, 20.46, 20.46, 20.46, 20.46, 20.46],
#         [21.46, 21.46, 21.46, 21.46, 21.46, 21.46],
#         [22.46, 22.46, 22.46, 22.46, 22.46, 22.46],
#         [23.46, 23.46, 23.46, 23.46, 23.46, 23.46],
#         [24.46, 24.46, 24.46, 24.46, 24.46, 24.46],
#         [25.46, 25.46, 25.46, 25.46, 25.46, 25.46],
#         [26.46, 26.46, 26.46, 26.46, 26.46, 26.46],
#         [27.46, 27.46, 27.46, 27.46, 27.46, 27.46]]))

# %%
plano = pd.DataFrame({'RM': x1.ravel(), 'INDUS' : x2.ravel()})
plano
# Out:
#         RM  INDUS
# 0    3.561   0.46
# 1    4.561   0.46
# 2    5.561   0.46
# 3    6.561   0.46
# 4    7.561   0.46
# ..     ...    ...
# 163  4.561  27.46
# 164  5.561  27.46
# 165  6.561  27.46
# 166  7.561  27.46
# 167  8.561  27.46
#
# [168 rows x 2 columns]

# %%
pred = slr.predict(plano).reshape(x1.shape)
pred = sc_y.inverse_transform(pred)
pred
# Out:
# /home/jordi/entornos/entorno_sic/lib/python3.11/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([[ 41.02916025,  46.51963684,  52.01011343,  57.50059002,
#          62.99106661,  68.4815432 ],
#        [ 38.73517499,  44.22565158,  49.71612818,  55.20660477,
#          60.69708136,  66.18755795],
#        [ 36.44118974,  41.93166633,  47.42214292,  52.91261951,
#          58.4030961 ,  63.89357269],
#        [ 34.14720448,  39.63768108,  45.12815767,  50.61863426,
#          56.10911085,  61.59958744],
#        [ 31.85321923,  37.34369582,  42.83417241,  48.324649  ,
#          53.81512559,  59.30560219],
#        [ 29.55923397,  35.04971057,  40.54018716,  46.03066375,
#          51.52114034,  57.01161693],
#        [ 27.26524872,  32.75572531,  38.2462019 ,  43.73667849,
#          49.22715508,  54.71763168],
#        [ 24.97126346,  30.46174006,  35.95221665,  41.44269324,
#          46.93316983,  52.42364642],
#        [ 22.67727821,  28.1677548 ,  33.65823139,  39.14870798,
#          44.63918457,  50.12966117],
#        [ 20.38329296,  25.87376955,  31.36424614,  36.85472273,
#          42.34519932,  47.83567591],
#        [ 18.0893077 ,  23.57978429,  29.07026088,  34.56073747,
#          40.05121407,  45.54169066],
#        [ 15.79532245,  21.28579904,  26.77627563,  32.26675222,
#          37.75722881,  43.2477054 ],
#        [ 13.50133719,  18.99181378,  24.48229037,  29.97276696,
#          35.46324356,  40.95372015],
#        [ 11.20735194,  16.69782853,  22.18830512,  27.67878171,
#          33.1692583 ,  38.65973489],
#        [  8.91336668,  14.40384327,  19.89431986,  25.38479646,
#          30.87527305,  36.36574964],
#        [  6.61938143,  12.10985802,  17.60033461,  23.0908112 ,
#          28.58128779,  34.07176438],
#        [  4.32539617,   9.81587276,  15.30634935,  20.79682595,
#          26.28730254,  31.77777913],
#        [  2.03141092,   7.52188751,  13.0123641 ,  18.50284069,
#          23.99331728,  29.48379387],
#        [ -0.26257434,   5.22790225,  10.71837885,  16.20885544,
#          21.69933203,  27.18980862],
#        [ -2.55655959,   2.933917  ,   8.42439359,  13.91487018,
#          19.40534677,  24.89582336],
#        [ -4.85054485,   0.63993174,   6.13040834,  11.62088493,
#          17.11136152,  22.60183811],
#        [ -7.1445301 ,  -1.65405351,   3.83642308,   9.32689967,
#          14.81737626,  20.30785285],
#        [ -9.43851536,  -3.94803876,   1.54243783,   7.03291442,
#          12.52339101,  18.0138676 ],
#        [-11.73250061,  -6.24202402,  -0.75154743,   4.73892916,
#          10.22940575,  15.71988235],
#        [-14.02648587,  -8.53600927,  -3.04553268,   2.44494391,
#           7.9354205 ,  13.42589709],
#        [-16.32047112, -10.82999453,  -5.33951794,   0.15095865,
#           5.64143524,  11.13191184],
#        [-18.61445638, -13.12397978,  -7.63350319,  -2.1430266 ,
#           3.34744999,   8.83792658],
#        [-20.90844163, -15.41796504,  -9.92748845,  -4.43701186,
#           1.05346473,   6.54394133]])

# %%
fig = plt.figure()
#ax = fig.gca()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x1, x2, pred, alpha=0.4)

ax.scatter3D(df['RM'], df['INDUS'], df['MEDV'], marker='.', color='red')
plt.show()

# %%
fig = plt.figure()
#ax = fig.gca()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x1, x2, pred, alpha=0.4)

ax.scatter3D(df['RM'], df['INDUS'], df['MEDV'], marker='.', color='red')
ax.view_init(elev=10, azim=5)
plt.show()
